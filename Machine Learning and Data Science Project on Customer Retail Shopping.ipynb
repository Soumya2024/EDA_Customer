# %% [markdown]
# ## This project aims to analyze the shopping behavior of customers in various retail store using machine learning techniques.
#
# #### The primary objective of this project is to identify the factors that influence customer shopping behavior and predict their future purchases. The project will involve data exploration, visualization, and analysis, followed by the application of unsupervised and supervised learning algorithms, including K-Means Clustering, Logistic Regression, Decision Trees, Random Forests, Linear Regression, Polynomial Regression, and Neural Networks. Finally evaluation of the results of these models.
#
# ## Important Libraries: Numpy, Pandas, Matplotlib, Scikit-learn
#
# #### Data Exploration: We are dealing with huge data and initially analysing the features and relation of the features with each other. Also using graphs of numerical and categorical features. It is a way to get to know data before working with it. Through survey and investigation, large datasets are readied for deeper, more structured analysis.
#
# #### Data Visualization: It’s a significant aspect of analysing data. Data visualization provides a good, organized pictorial representation of the data which makes it easier to understand, observe, analyze. Python provides multiple libraries for visualization. Here we are using Matplotlib which is an easy-to-use, low-level data visualization library that is built on NumPy arrays.
#
# #### Standard Scaler: We applied StandardScaler to resize the distribution of values ​​so that the mean of the observed values ​​is 0 and the standard deviation is 1.
#
# #### PCA(Principal Component Analysis): The Principal Component Analysis is a popular unsupervised learning technique for reducing the dimensionality of data. We have used it to find the most significant features for training and testing of our model for optimum result.
#
# #### Unsupervised learning through K-Means Clustering: K-Means Clustering is an Unsupervised Learning algorithm. We drew the graph of WCSS vs No. of clusters, known as Elbow method.
#
# #### Supervised Learning- Regression: Linear Regression, Decision Tree, Random Forest. Also evaluated the performance through MSE and R-squared.
#
# #### Supervised Learning – Classification:  Logistic Regression, Decision Tree, Random Forest. Also evaluated the performance through Accuracy score.

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/Users/soumyaprasadchandra/Downloads/customer_shopping_data.csv")

# %%
df1.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
df1.tail()
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul

# %%
df1.shape
# Out:
# (99457, 10)

# %%
df1.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
df1.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.nunique()
# Out:
# invoice_no        99457
# customer_id       99457
# gender                2
# age                  52
# category              8
# quantity              5
# price                40
# payment_method        3
# invoice_date        797
# shopping_mall        10
# dtype: int64

# %%
a = df1['category'].unique()

# %%
print(a)
# Out:
# ['Clothing' 'Shoes' 'Books' 'Cosmetics' 'Food & Beverage' 'Toys'
#  'Technology' 'Souvenir']

# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df1['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df1['gender'].value_counts()
# Out:
# Female    59482
# Male      39975
# Name: gender, dtype: int64

# %%
df1['gender'].value_counts().index
# Out:
# Index(['Female', 'Male'], dtype='object')

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df1, x='gender',  palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.pie(df['gender'].value_counts(), labels=df['gender'].value_counts().index, explode=[0.2,0.1], autopct='%1.1f%%',textprops={'fontsize':14})
#hfont = {}
plt.title('Gender', size=20)
plt.show()

# %%
import plotly.express as px

# %%
df['gender'].value_counts().values
# Out:
# array([59482, 39975])

# %%
df['category'].unique()
# Out:
# array(['Clothing', 'Shoes', 'Books', 'Cosmetics', 'Food & Beverage',
#        'Toys', 'Technology', 'Souvenir'], dtype=object)

# %%
df['category'].value_counts()
# Out:
# Clothing           34487
# Cosmetics          15097
# Food & Beverage    14776
# Toys               10087
# Shoes              10034
# Souvenir            4999
# Technology          4996
# Books               4981
# Name: category, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df1, x='category', palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df1, x='category', hue='gender', palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(data = df1, x='category', hue= 'payment_method', palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='category', hue= 'shopping_mall', data=df1, palette='hls')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.pie(df['category'].value_counts(), labels=df['category'].value_counts().index, autopct='%1.1f%%')
plt.title('category', size=30)
plt.show()

# %%
df['quantity'].unique()
# Out:
# array([5, 3, 1, 4, 2])

# %%
df['quantity'].value_counts()
# Out:
# 3    20149
# 5    19990
# 2    19828
# 1    19767
# 4    19723
# Name: quantity, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x ='quantity' ,data=df1, palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = 'quantity', hue='gender', data = df1, palette='hls')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.pie(df['quantity'].value_counts(), labels=df['quantity'].value_counts().index, autopct='%1.1f%%')
#hfont = {'fontname':'serif', 'weight': 'bold'}
plt.show()
plt.title('Quantity', size=30, )
# Out:
# Text(0.5, 1.0, 'Quantity')

# %%
df['payment_method'].unique()
# Out:
# array(['Credit Card', 'Debit Card', 'Cash'], dtype=object)

# %%
df['payment_method'].value_counts()
# Out:
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: payment_method, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = 'payment_method', data=df1, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = 'payment_method', hue='gender', data=df1, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = 'payment_method', hue = 'category' ,data=df1, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.pie(df1['payment_method'].value_counts(), labels=df1['payment_method'].value_counts(), autopct='%1.1f%%')
plt.title(' Payment Method', size=30)
plt.show()

# %%
df['shopping_mall'].value_counts()
# Out:
# Mall of Istanbul     19943
# Kanyon               19823
# Metrocity            15011
# Metropol AVM         10161
# Istinye Park          9781
# Zorlu Center          5075
# Cevahir AVM           4991
# Forum Istanbul        4947
# Viaport Outlet        4914
# Emaar Square Mall     4811
# Name: shopping_mall, dtype: int64

# %%
plt.figure(figsize=(18,6))
sns.countplot(x = 'shopping_mall', data=df1, palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.pie(df['shopping_mall'].value_counts(), labels=df1['shopping_mall'].value_counts().index, autopct='%1.1f%%', explode=[0.2,0.1,0.1,0.4,0.2,0.7,0.1,0.2,0.1,0.2])
plt.title('shopping_mall', size=20)
plt.show()

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
object_cols = df.select_dtypes(include=['object']).columns.tolist()

print(" Numerical columns ", numerical_cols)
print(" Object columns:",  object_cols)
# Out:
#  Numerical columns  ['age', 'quantity', 'price']
#  Object columns: ['invoice_no', 'customer_id', 'gender', 'category', 'payment_method', 'invoice_date', 'shopping_mall']

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.histplot(df[i], kde=True, bins=20, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.distplot(df[i], kde = True, bins = 20)
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.boxplot(df1[i], palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.violinplot(df1[i], palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
print(" Numerical columns: ", numerical_cols)
print(" Object Columns :", object_cols)
# Out:
#  Numerical columns:  ['age', 'quantity', 'price']
#  Object Columns : ['invoice_no', 'customer_id', 'gender', 'category', 'payment_method', 'invoice_date', 'shopping_mall']

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.barplot(x = df1['gender'], y = df1[i], data=df1, ci=None, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.barplot(x = df1['gender'], y = df1[i], hue = 'shopping_mall', data=df1, ci=None, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.barplot(x = df1['category'], y = df1[i], data=df1, ci=None, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.barplot(x = df1['category'], y = df1[i], hue = 'gender', data=df1, ci=None, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.barplot(x = df1['payment_method'], y = df1[i], data=df1, ci=None, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.barplot(x = df1['payment_method'], y = df1[i],hue = 'category', data=df1, ci=None, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    plt.figure(figsize=(15,6))
    sns.barplot(x = df1['shopping_mall'], y = df1[i], data=df1, ci=None, palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in numerical_cols:
    for j in numerical_cols:
        if i != j:
            plt.figure(figsize=(15,6))
            sns.lineplot(x = df1[i], y = df1[j], ci = None, palette='hls')
            plt.xticks(rotation=90)
            plt.xticks()

# %%
for i in numerical_cols:
    for j in numerical_cols:
        if i != j:
            plt.figure(figsize=(15,6))
            sns.lineplot(x = df1[i], y = df1[j], hue = 'gender', data = df1, ci = None, palette='hls')
            plt.xticks(rotation=90)
            plt.xticks()

# %%
df1['invoice_date'] = pd.to_datetime(df1['invoice_date'])

# %%
df1['invoice_date']
# Out:
# 0       2022-05-08
# 1       2021-12-12
# 2       2021-09-11
# 3       2021-05-16
# 4       2021-10-24
#            ...
# 99452   2022-09-21
# 99453   2021-09-22
# 99454   2021-03-28
# 99455   2021-03-16
# 99456   2022-10-15
# Name: invoice_date, Length: 99457, dtype: datetime64[ns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  datetime64[ns]
#  9   shopping_mall   99457 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 7.6+ MB

# %%
sales_by_date = df1.groupby('invoice_date')['price'].sum()
plt.figure(figsize=(15,6))
plt.plot(sales_by_date.index, sales_by_date.values)
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales by Date')
plt.xticks(rotation=90)
plt.show()

# %%
df1['month'] = pd.DatetimeIndex(df1['invoice_date']).month
sales_by_month = df1.groupby('month')['price'].sum()

plt.figure(figsize=(15,6))
plt.bar(sales_by_month.index, sales_by_month.values)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Total Sales by Month')
plt.xticks(rotation=90)
plt.show()

# %%
df1['month'] = pd.DatetimeIndex(df1['invoice_date']).month
sales_by_month = df1.groupby('month')['price'].sum()

plt.figure(figsize=(15,6))
plt.plot(sales_by_month.index, sales_by_month.values)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Total Sales by Month')
plt.xticks(rotation=90)
plt.show()

# %%
df1['month'] = pd.DatetimeIndex(df1['invoice_date']).month
sales_by_month_categroy = df1.groupby(['month', 'category'])['price'].sum().unstack()

plt.figure(figsize=(15,6))
sns.heatmap(sales_by_month_categroy, cmap='Blues')
plt.xlabel('Category')
plt.ylabel('Month')
plt.title('Sales by Month and Category')
# Out:
# Text(0.5, 1.0, 'Sales by Month and Category')

# %%
sales_by_month_categroy = df.groupby(['month', 'category'])['price'].sum().reset_index()

plt.figure(figsize=(15,6))
sns.boxplot(x = 'category', y = 'price', data=sales_by_month_categroy)
plt.xlabel('category')
plt.ylabel('Sales')
plt.title('Distribution of Sales by Category')
plt.show()

# %%
sales_by_month_categroy
# Out:
#     month         category       price
# 0       1            Books    23603.70
# 1       1         Clothing  3173646.08
# 2       1        Cosmetics   199030.70
# 3       1  Food & Beverage    23508.85
# 4       1            Shoes  1864728.19
# ..    ...              ...         ...
# 91     12  Food & Beverage    18984.90
# 92     12            Shoes  1447009.87
# 93     12         Souvenir    13407.39
# 94     12       Technology  1228500.00
# 95     12             Toys    93578.24
#
# [96 rows x 3 columns]

# %%
plt.figure(figsize=(15,6))
sns.histplot(df1['invoice_date'], bins=30, kde=True)
plt.xlabel('Date')
plt.ylabel('Frequancy')
plt.title('Distribution of Sales by Date')
plt.show()

# %%
sales_by_month = df1.resample('M', on = 'invoice_date')['price'].sum()


plt.figure(figsize=(15,6))
plt.plot(sales_by_month.index, sales_by_month.values)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Sales by Month')
plt.show()

# %%
sales_by_month = df1.resample('W', on='invoice_date')['price'].sum()


plt.figure(figsize=(15,6))
plt.plot(sales_by_month.index, sales_by_month.values)
plt.xlabel('Week')
plt.ylabel('Sales')
plt.title('Sales by Week')
plt.show()

# %%
df1.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  month
# 0    Credit Card   2022-05-08          Kanyon      5
# 1     Debit Card   2021-12-12  Forum Istanbul     12
# 2           Cash   2021-09-11       Metrocity      9
# 3    Credit Card   2021-05-16    Metropol AVM      5
# 4           Cash   2021-10-24          Kanyon     10

# %%
data1 = pd.get_dummies(df1, columns=['gender', 'category', 'payment_method', 'shopping_mall'])

# %%
data1.head()
# Out:
#   invoice_no customer_id  age  quantity    price invoice_date  month  \
# 0    I138884     C241288   28         5  1500.40   2022-05-08      5
# 1    I317333     C111565   21         3  1800.51   2021-12-12     12
# 2    I127801     C266599   20         1   300.08   2021-09-11      9
# 3    I173702     C988172   66         5  3000.85   2021-05-16      5
# 4    I337046     C189076   53         4    60.60   2021-10-24     10
#
#    gender_Female  gender_Male  category_Books  ...  shopping_mall_Cevahir AVM  \
# 0              1            0               0  ...                          0
# 1              0            1               0  ...                          0
# 2              0            1               0  ...                          0
# 3              1            0               0  ...                          0
# 4              1            0               1  ...                          0
#
#    shopping_mall_Emaar Square Mall  shopping_mall_Forum Istanbul  \
# ...

# %%
data1.tail()
# Out:
#       invoice_no customer_id  age  quantity    price invoice_date  month  \
# 99452    I219422     C441542   45         5    58.65   2022-09-21      9
# 99453    I325143     C569580   27         2    10.46   2021-09-22      9
# 99454    I824010     C103292   63         2    10.46   2021-03-28      3
# 99455    I702964     C800631   56         4  4200.00   2021-03-16      3
# 99456    I232867     C273973   36         3    35.19   2022-10-15     10
#
#        gender_Female  gender_Male  category_Books  ...  \
# 99452              1            0               0  ...
# 99453              0            1               0  ...
# 99454              0            1               0  ...
# 99455              0            1               0  ...
# 99456              1            0               0  ...
#
#        shopping_mall_Cevahir AVM  shopping_mall_Emaar Square Mall  \
# 99452                          0                                0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   invoice_no                       99457 non-null  object
#  1   customer_id                      99457 non-null  object
#  2   age                              99457 non-null  int64
#  3   quantity                         99457 non-null  int64
#  4   price                            99457 non-null  float64
#  5   invoice_date                     99457 non-null  datetime64[ns]
#  6   month                            99457 non-null  int64
#  7   gender_Female                    99457 non-null  uint8
#  8   gender_Male                      99457 non-null  uint8
#  9   category_Books                   99457 non-null  uint8
#  10  category_Clothing                99457 non-null  uint8
#  11  category_Cosmetics               99457 non-null  uint8
# ...

# %%
df_clean = data1.drop(['invoice_no', 'customer_id', 'invoice_date'], axis=1)

# %%
df_clean.columns
# Out:
# Index(['age', 'quantity', 'price', 'month', 'gender_Female', 'gender_Male',
#        'category_Books', 'category_Clothing', 'category_Cosmetics',
#        'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
#        'category_Technology', 'category_Toys', 'payment_method_Cash',
#        'payment_method_Credit Card', 'payment_method_Debit Card',
#        'shopping_mall_Cevahir AVM', 'shopping_mall_Emaar Square Mall',
#        'shopping_mall_Forum Istanbul', 'shopping_mall_Istinye Park',
#        'shopping_mall_Kanyon', 'shopping_mall_Mall of Istanbul',
#        'shopping_mall_Metrocity', 'shopping_mall_Metropol AVM',
#        'shopping_mall_Viaport Outlet', 'shopping_mall_Zorlu Center'],
#       dtype='object')

# %%
df_corr = df_clean.corr()

# %%
df_corr
# Out:
#                                       age  quantity     price     month  \
# age                              1.000000  0.000667  0.001694  0.005692
# quantity                         0.000667  1.000000  0.344880  0.005353
# price                            0.001694  0.344880  1.000000 -0.002933
# month                            0.005692  0.005353 -0.002933  1.000000
# gender_Female                    0.002150  0.000131 -0.001450 -0.000088
# gender_Male                     -0.002150 -0.000131  0.001450  0.000088
# category_Books                   0.001758  0.000715 -0.157036  0.000334
# category_Clothing               -0.000868 -0.000318  0.163976  0.001398
# category_Cosmetics               0.004334  0.002424 -0.254765 -0.000651
# category_Food & Beverage        -0.002025 -0.002034 -0.298954  0.000982
# category_Shoes                   0.000623  0.001904  0.397954 -0.005687
# category_Souvenir               -0.000522 -0.004662 -0.159944 -0.006091
# ...

# %%
plt.figure(figsize=(30, 10))
matrix = np.triu(df_corr)
sns.heatmap(df_corr, annot=True, linewidth=.8, mask=matrix, cmap='rocket');
plt.show()

# %%
corr = df_corr
corr
# Out:
#                                       age  quantity     price     month  \
# age                              1.000000  0.000667  0.001694  0.005692
# quantity                         0.000667  1.000000  0.344880  0.005353
# price                            0.001694  0.344880  1.000000 -0.002933
# month                            0.005692  0.005353 -0.002933  1.000000
# gender_Female                    0.002150  0.000131 -0.001450 -0.000088
# gender_Male                     -0.002150 -0.000131  0.001450  0.000088
# category_Books                   0.001758  0.000715 -0.157036  0.000334
# category_Clothing               -0.000868 -0.000318  0.163976  0.001398
# category_Cosmetics               0.004334  0.002424 -0.254765 -0.000651
# category_Food & Beverage        -0.002025 -0.002034 -0.298954  0.000982
# category_Shoes                   0.000623  0.001904  0.397954 -0.005687
# category_Souvenir               -0.000522 -0.004662 -0.159944 -0.006091
# ...

# %%
high_corr_feature = set()
for i in range(len(corr.columns)):
    for j in range(i):
        if abs(corr.iloc[i, j]) >= 0.1:
            high_corr_feature.add((corr.columns[i], corr.columns[j], corr.iloc[i, j]))
            
for feature_pair in high_corr_feature:
    print(feature_pair)
# Out:
# ('category_Toys', 'category_Cosmetics', -0.14212228241671207)
# ('shopping_mall_Kanyon', 'shopping_mall_Cevahir AVM', -0.1146809935572282)
# ('shopping_mall_Mall of Istanbul', 'shopping_mall_Istinye Park', -0.1653967453026517)
# ('category_Technology', 'category_Clothing', -0.16755454799676237)
# ('shopping_mall_Kanyon', 'shopping_mall_Emaar Square Mall', -0.11248690598525163)
# ('shopping_mall_Zorlu Center', 'shopping_mall_Mall of Istanbul', -0.11613065597136397)
# ('category_Souvenir', 'price', -0.15994388350871738)
# ('shopping_mall_Viaport Outlet', 'shopping_mall_Mall of Istanbul', -0.11417639604026371)
# ('shopping_mall_Zorlu Center', 'shopping_mall_Kanyon', -0.11569347353925404)
# ('category_Clothing', 'category_Books', -0.16728954396122633)
# ('category_Toys', 'category_Clothing', -0.24476899607366512)
# ('category_Toys', 'category_Food & Beverage', -0.14033648147692132)
# ('category_Shoes', 'category_Clothing', -0.24405274998490123)
# ...

# %% [markdown]
# ## PCA & Standard Scaler:

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df_corr.columns
# Out:
# Index(['age', 'quantity', 'price', 'month', 'gender_Female', 'gender_Male',
#        'category_Books', 'category_Clothing', 'category_Cosmetics',
#        'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
#        'category_Technology', 'category_Toys', 'payment_method_Cash',
#        'payment_method_Credit Card', 'payment_method_Debit Card',
#        'shopping_mall_Cevahir AVM', 'shopping_mall_Emaar Square Mall',
#        'shopping_mall_Forum Istanbul', 'shopping_mall_Istinye Park',
#        'shopping_mall_Kanyon', 'shopping_mall_Mall of Istanbul',
#        'shopping_mall_Metrocity', 'shopping_mall_Metropol AVM',
#        'shopping_mall_Viaport Outlet', 'shopping_mall_Zorlu Center'],
#       dtype='object')

# %%
X = df_clean[['age', 'quantity', 'price', 'month', 'gender_Female', 'gender_Male',
       'category_Books', 'category_Clothing', 'category_Cosmetics',
       'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
       'category_Technology', 'category_Toys', 'payment_method_Cash',
       'payment_method_Credit Card', 'payment_method_Debit Card',
       'shopping_mall_Cevahir AVM', 'shopping_mall_Emaar Square Mall',
       'shopping_mall_Forum Istanbul', 'shopping_mall_Istinye Park',
       'shopping_mall_Kanyon', 'shopping_mall_Mall of Istanbul',
       'shopping_mall_Metrocity', 'shopping_mall_Metropol AVM',
       'shopping_mall_Viaport Outlet', 'shopping_mall_Zorlu Center']]

scaler  = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=10)
X_pca = pca.fit_transform(X_scaled)

# %%
pca
# Out:
# PCA(n_components=10)

# %%
len(X_pca)
# Out:
# 99457

# %%
X_pca
# Out:
# array([[ 0.93214585,  1.49136991,  1.45318583, ...,  0.03296625,
#         -0.02997826,  0.00689019],
#        [ 1.99475958, -1.25845189,  0.51786717, ..., -0.05740719,
#         -1.20485824,  1.15412979],
#        [ 0.17896691, -1.77422038, -1.36242099, ...,  0.4118595 ,
#          1.26817881, -0.21161074],
#        ...,
#        [-0.95840176, -2.05454123,  0.51713784, ..., -1.48891287,
#          1.66423211, -1.5309264 ],
#        [ 4.94929137, -0.52639707, -1.30792167, ..., -0.25133311,
#         -1.23252224,  0.18572567],
#        [-1.30096944,  0.9139938 ,  1.46534644, ..., -0.21216095,
#          0.91409892,  0.27039061]])

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_pca)
    wcss.append(kmeans.inertia_)
    print(f"n_clusters: {i}, WCSS: {kmeans.inertia_}")
plt.plot(range(1, 11),wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# n_clusters: 1, WCSS: 1418797.7192879308
# n_clusters: 2, WCSS: 1219881.0391554548
# n_clusters: 3, WCSS: 1099944.8651928916
# n_clusters: 4, WCSS: 1013721.2051801906
# n_clusters: 5, WCSS: 928136.551425936
# n_clusters: 6, WCSS: 859402.6579894959
# n_clusters: 7, WCSS: 827304.6727522583
# n_clusters: 8, WCSS: 779527.4095842174
# n_clusters: 9, WCSS: 758134.1519721019
# n_clusters: 10, WCSS: 722712.1389142917

# %%
# was error as "AttributeError : 'NoneType' object has no attribute 'split' "
# pip show threadpoolctl
# pip install threadpoolctl --upgrade

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
kmeans.fit(X_pca)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# %%
labels
# Out:
# array([2, 0, 1, ..., 1, 0, 2], dtype=int32)

# %%
centers
# Out:
# array([[ 2.68170896,  0.78005983,  0.03194447,  1.5478562 ,  0.2254794 ,
#          0.05951709,  0.08083402, -0.14218328,  0.11237031, -0.01014022],
#        [ 0.20496047, -1.72887139,  0.02682377, -0.39021094, -0.0826546 ,
#         -0.02580281,  0.02976754, -0.39259512,  0.07794519,  0.1745666 ],
#        [-0.54537343,  1.05630283, -0.03849019, -0.42866358, -0.07493515,
#         -0.01998736,  0.03159205, -0.40900811,  0.08859694,  0.16858465],
#        [-1.03240847, -0.2492214 ,  0.03063564,  0.71735635,  0.19013243,
#          0.05854302, -0.21291187,  2.03708705, -0.49358473, -0.80873926]])

# %%
data_new = df_clean.copy()

# %%
data_new.columns
# Out:
# Index(['age', 'quantity', 'price', 'month', 'gender_Female', 'gender_Male',
#        'category_Books', 'category_Clothing', 'category_Cosmetics',
#        'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
#        'category_Technology', 'category_Toys', 'payment_method_Cash',
#        'payment_method_Credit Card', 'payment_method_Debit Card',
#        'shopping_mall_Cevahir AVM', 'shopping_mall_Emaar Square Mall',
#        'shopping_mall_Forum Istanbul', 'shopping_mall_Istinye Park',
#        'shopping_mall_Kanyon', 'shopping_mall_Mall of Istanbul',
#        'shopping_mall_Metrocity', 'shopping_mall_Metropol AVM',
#        'shopping_mall_Viaport Outlet', 'shopping_mall_Zorlu Center'],
#       dtype='object')

# %% [markdown]
# #### importances = model.featureimportances # extract feature importances feature_names =
# # X.columns # get feature names from X dataframe

# %% [markdown]
# ## Create a datafrane to store feature importances

# %% [markdown]
# #### feature_importances  pd.DataFrame({'feature':feature_names, 'importances':importances})

# %% [markdown]
# ## sort the features by importance in descending order

# %% [markdown]
# #### feature_importances = feature_importances.sort_value(by='importance', ascending=False)

# %% [markdown]
# ## select the top 10 features

# %% [markdown]
# #### top_10_features = feature_importances.head(10)['feature'].tolist()

# %% [markdown]
# #### print("top 10 feature:", top_10_features)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score




X = data_new.drop('price', axis=1)
y = data_new['price']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state = 0)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)


models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor()]


model_names = ['Linear Regression', 'Decision Tree', 'Random Forest']


for i, model in enumerate(models):
    print(model_names[i] + ':')
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print('MSE: ', mean_squared_error(y_test, y_pred))
    print('R-Squared: ', r2_score(y_test, y_pred))
    print('---------------------------------------')
# Out:
# Linear Regression:
# MSE:  1.9416368020681997e+26
# R-Squared:  -2.156291737032689e+20
# ---------------------------------------
# Decision Tree:
# MSE:  3.1721600564498965e-21
# R-Squared:  1.0
# ---------------------------------------
# Random Forest:
# MSE:  3.594464901366835e-22
# R-Squared:  1.0
# ---------------------------------------

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import KBinsDiscretizer

# Assuming 'data_new' is a DataFrame with continuous target variable 'payment_method_Cash'

# Convert continuous target variable into categorical labels using binning
n_bins = 5  # Number of bins for binning
encoder = KBinsDiscretizer(n_bins=n_bins, encode='ordinal')
data_new['payment_method_Cash'] = encoder.fit_transform(data_new['payment_method_Cash'].values.reshape(-1, 1))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_new.drop('payment_method_Cash', axis=1),
                                                    data_new['payment_method_Cash'],
                                                    random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(data_new.drop('payment_method_Cash'),
                                                    data_new['payment_method_Cash'],
                                                    random_state=42)



scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)



logreg = LogisticRegression()
logreg.fit(X_train, y_train)


from sklearn.metrics import accuracy_score


y_pred = logreg.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

dt = DecisionTreeClassifier(max_depth = 3)

dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)


acc = accuracy_score(y_test, y_pred)
print(" Decision Tree Accuracy : ", acc)


rf = RandomForestClassifier(n_estimators=100)

rf.fit(X_train, y_train)


y_pred = rf.predict(X_test)

acc = accuracy_score(y_test, y_pred)
print(" Random Forest Accuracy : ", acc)
# Out:
#  Decision Tree Accuracy :  1.0
#  Random Forest Accuracy :  1.0

# %%
data_new.columns
# Out:
# Index(['age', 'quantity', 'price', 'month', 'gender_Female', 'gender_Male',
#        'category_Books', 'category_Clothing', 'category_Cosmetics',
#        'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
#        'category_Technology', 'category_Toys', 'payment_method_Cash',
#        'payment_method_Credit Card', 'payment_method_Debit Card',
#        'shopping_mall_Cevahir AVM', 'shopping_mall_Emaar Square Mall',
#        'shopping_mall_Forum Istanbul', 'shopping_mall_Istinye Park',
#        'shopping_mall_Kanyon', 'shopping_mall_Mall of Istanbul',
#        'shopping_mall_Metrocity', 'shopping_mall_Metropol AVM',
#        'shopping_mall_Viaport Outlet', 'shopping_mall_Zorlu Center'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall', 'month'],
#       dtype='object')

# %%
df2 = df[['gender', 'age', 'category', 'quantity', 'price', 'payment_method', 'shopping_mall']]

# %%
df3 = df2[0:20000]

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
df3['gender'] = label_encoder.fit_transform(df3['gender'])
df3['category'] = label_encoder.fit_transform(df3['category'])
df3['payment_method'] = label_encoder.fit_transform(df3['payment_method'])
df3['shopping_mall'] = label_encoder.fit_transform(df3['shopping_mall'])

# %%
similarity_matrix = cosine_similarity(df3)

# %%
similarity_matrix
# Out:
# array([[1.        , 0.99997147, 0.99869509, ..., 0.98227221, 0.98328954,
#         0.95878028],
#        [0.99997147, 1.        , 0.99831054, ..., 0.98092233, 0.98205064,
#         0.95678783],
#        [0.99869509, 0.99831054, 1.        , ..., 0.99013547, 0.99098724,
#         0.97169813],
#        ...,
#        [0.98227221, 0.98092233, 0.99013547, ..., 1.        , 0.99763049,
#         0.99384684],
#        [0.98328954, 0.98205064, 0.99098724, ..., 0.99763049, 1.        ,
#         0.99378744],
#        [0.95878028, 0.95678783, 0.97169813, ..., 0.99384684, 0.99378744,
#         1.        ]])

# %%
user_index = df3.index[-1]

similarity_scores = list(enumerate(similarity_matrix[user_index]))

sorted_scores = sorted(similarity_scores, key = lambda x: x[1], reverse=True)


top_similar_customers = [i[0] for i in sorted_scores[1:6]]

recommened_products = df3.loc[top_similar_customers, 'category'].value_counts()#.index

print(" Recommended products based on your preferences: ")
print(recommened_products)
# Out:
#  Recommended products based on your preferences:
# 7    5
# Name: category, dtype: int64

# %%
top_similar_customers
# Out:
# [18162, 19290, 548, 19666, 11986]

# %%
recommened_products
# Out:
# 7    5
# Name: category, dtype: int64

# %%
import joblib
joblib.dump(similarity_matrix, "similarity_matrix.joblib")
# Out:
# ['similarity_matrix.joblib']
